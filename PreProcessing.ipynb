# %% [markdown]
# <a href="https://colab.research.google.com/github/Synaptic-rayan/Machine-Learning/blob/main/PreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import yaml
from sklearn.model_selection import train_test_split

root_dir = "/content/trafic_data"
valid_formats = [".jpg", ".jpeg", ".png", ".txt"]
image_path = "/content/trafic_data/train/images"
label_path = "/content/trafic_data/train/labels"

def file_paths(root, valid_formats):
    """
    Get the full path to each image/label in the dataset.
    """
    file_paths = []

    for dirpath, dirnames, filenames in os.walk(root):
        for filename in filenames:
            extension = os.path.splitext(filename)[1].lower()
            if extension in valid_formats:
                file_path = os.path.join(dirpath, filename)
                file_paths.append(file_path)

    return file_paths

def write_image_label(images_path, labels_path, img_path):
    img_name = os.path.splitext(os.path.basename(img_path))[0]
    img = cv2.imread(img_path)
    if img is not None:
        cv2.imwrite(f"{images_path}/{img_name}.jpg", img)
    else:
        print(f"Error: Could not read image '{img_path}'")

    with open(f"{labels_path}/{img_name}.txt", "w") as label_file:
        label_file_path = os.path.join(label_path, f"{img_name}.txt")
        try:
            with open(label_file_path, "r") as original_label_file:
                label_file.write(original_label_file.read())
        except FileNotFoundError:
            print(f"Warning: Label file '{label_file_path}' not found.")

def write_to_file(images_path, labels_path, X):
    """
    Write images and their corresponding labels to directories.
    """
    os.makedirs(images_path, exist_ok=True)
    os.makedirs(labels_path, exist_ok=True)

    for img_path in X:
        write_image_label(images_path, labels_path, img_path)

# Debug: Print the paths being used
print("Image directory path:", os.path.join(root_dir, "train/images"))
print("Label directory path:", os.path.join(root_dir, "train/labels"))

image_paths = file_paths(os.path.join(root_dir, "train/images"), valid_formats[:3])
label_paths = file_paths(os.path.join(root_dir, "train/labels"), valid_formats[-1:])

# Debug: Print the collected image and label paths
print("Collected image paths:", image_paths)
print("Collected label paths:", label_paths)

# Check if data is available for splitting
if not image_paths or not label_paths:
    print("Error: No data available for splitting.")
else:
    # Split data into train, validation, and test sets
    X_train_val, X_test, y_train_val, y_test = train_test_split(image_paths, label_paths, test_size=0.3, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.7, random_state=42)

    write_to_file("datasets/images/train", "datasets/labels/train", X_train)
    write_to_file("datasets/images/valid", "datasets/labels/valid", X_val)
    write_to_file("datasets/images/test", "datasets/labels/test", X_test)

    data = {
        "path": "../datasets",
        "train": "images/train",
        "val": "images/valid",
        "test": "images/test",
        "names": ["number plate"]
    }

    with open("number-plate.yaml", "w") as f:
        yaml.dump(data, f)
# Out:
# Image directory path: /content/trafic_data/train/images
# Label directory path: /content/trafic_data/train/labels
# Collected image paths: ['/content/trafic_data/train/images/Dipto_532_JPG.rf.b15555ac5da422d0b1ebd467d625f45e.jpg', '/content/trafic_data/train/images/Pias--123-_jpg.rf.a44d26f68b65aaeba4ab80e0e08fe320.jpg', '/content/trafic_data/train/images/Pias--466-_jpg.rf.0430763a1f2aad84f6f6ba8b8072fd01.jpg', '/content/trafic_data/train/images/121_jpg.rf.12663332346e88d4786511c0dcc0515e.jpg', '/content/trafic_data/train/images/Dipto_553_jpg.rf.76b65201836d8f6200d3274571b867c1.jpg', '/content/trafic_data/train/images/Dipto_616_jpg.rf.118758f6f747c79091dad90cae6485b9.jpg', '/content/trafic_data/train/images/Numan_-239-_jpg.rf.1386b2c3736a7c37f2d957d79b21d081.jpg', '/content/trafic_data/train/images/Pias--504-_jpg.rf.4049832e129b278c6ebf5f5c3114770b.jpg', '/content/trafic_data/train/images/Navid_158_jpg.rf.510a183d33917399477af4e460740cde.jpg', '/content/trafic_data/train/images/Navid_337_jpg.rf.a9bf4e9635e3148d30cd44194aa3d3ca.jpg', '/content/trafic_data/train/images/107_jpg.rf.18145cfc61bb4fb65a51b7be59dda81a.jpg', '/content/trafic_data/train/images/Navid_514_jpg.rf.9019bdafbfb09319c3ce62f7605ddc37.jpg', '/content/trafic_data/train/images/224_jpg.rf.d7afc45c9cc42f530eb4599af5fb3d4c.jpg', '/content/trafic_data/train/images/Dipto_-316_jpg.rf.fedfbb43e3e1a5126ed1840f414f22ed.jpg', '/content/trafic_data/train/images/Dipto_-79_jpg.rf.589a6e1ca858dd710317d67117c84438.jpg', '/content/trafic_data/train/images/Navid_301_jpg.rf.f311100d759bce8f1df452a2d4570b4d.jpg', '/content/trafic_data/train/images/Numan_-149-_jpg.rf.639f7926475894fdfa46fbe12fcfa8c2.jpg', '/content/trafic_data/train/images/Navid_479_jpg.rf.96df31626cf939f9e2f047c8bd02afa2.jpg', '/content/trafic_data/train/images/Dipto_566_jpg.rf.20897c0f2082bbedd35f534904110e49.jpg', '/content/trafic_data/train/images/Navid_121_jpg.rf.e9810a2a25db4634aeeef75204cd786a.jpg', '/content/trafic_data/train/images/Dipto_705_jpg.rf.01e39033d800316ab7096626633fdd3a.jpg', '/content/trafic_data/train/images/Navid_510_jpg.rf.43da36d06e371cd204c256a0f72afc59.jpg', '/content/trafic_data/train/images/Pias--527-_jpg.rf.e1a072c17f9c93db32cab6ce1f699930.jpg', '/content/trafic_data/train/images/Numan_-414-_jpg.rf.d9c3ae01eeff8c3c4bd350599bc44961.jpg', '/content/trafic_data/train/images/Navid_111_jpg.rf.248dff0938848430091be2b8a90192ad.jpg', '/content/trafic_data/train/images/Dipto_855_jpg.rf.2ac4f215e8065ae71d1ed740766191fb.jpg', '/content/trafic_data/train/images/Dipto_710_jpg.rf.09218c81278773d17bfcc1b50c6da868.jpg', '/content/trafic_data/train/images/Dipto_745_jpg.rf.07e2ef15743f2085c737e2758036320b.jpg', '/content/trafic_data/train/images/Navid_76_jpg.rf.4955e43cb67fc5a10908457f4db26403.jpg', '/content/trafic_data/train/images/82_jpg.rf.ea9421e0b3ad2c8c2a3deb8372211859.jpg', '/content/trafic_data/train/images/Pias--463-_jpg.rf.f9c315eb503e4fcd65ff336e00578294.jpg', '/content/trafic_data/train/images/Dipto_847_jpg.rf.48c0725007759c63115aa10408ecab79.jpg', '/content/trafic_data/train/images/Numan_-39-_jpg.rf.be021f0d1d1b7c54f9282776f9d3530e.jpg', '/content/trafic_data/train/images/Navid_72_jpg.rf.2959d8bdfd8c169459a193803a443656.jpg', '/content/trafic_data/train/images/Dipto_-46_jpg.rf.8b88f7cd2a8b7448f0ec88f8440f3e0f.jpg', '/content/trafic_data/train/images/Dipto_-167_jpg.rf.4be9339c78c6b92caf8e6f77d244b192.jpg', '/content/trafic_data/train/images/Navid_603_JPG.rf.76645bb0e6dc9fdfdc0309a37138f0cb.jpg', '/content/trafic_data/train/images/Numan_-348-_jpg.rf.db65b887fd9afbce82834018845a8e85.jpg', '/content/trafic_data/train/images/Navid_766_jpg.rf.1b50e7e80647c2e020ab90f8bd3ffb0d.jpg', '/content/trafic_data/train/images/Navid_476_jpg.rf.c49d90e41da4c630220c08753e31c858.jpg', '/content/trafic_data/train/images/Navid_671_jpg.rf.99a77fe4fbaf36af358c8ec18ea2e782.jpg', '/content/trafic_data/train/images/Numan_--18-_jpg.rf.237b4298b64abba8c972983b8bf047ef.jpg', '/content/trafic_data/train/images/Dipto_574_jpg.rf.ef88aeed38d92e91c137e8ba337e004c.jpg', '/content/trafic_data/train/images/Navid_204_jpg.rf.ef1b5ad7e4aa3af66fb9 ...
# Collected label paths: ['/content/trafic_data/train/labels/Dipto_730_jpg.rf.54c03c3349a270b8dc7e5b0b240da7b5.txt', '/content/trafic_data/train/labels/Navid_368_jpg.rf.14590cbddc2cf9f31de2ad9198d923ca.txt', '/content/trafic_data/train/labels/Dipto_-296_jpg.rf.9cfb8fb398cae5124cfc8a991b946086.txt', '/content/trafic_data/train/labels/212_jpg.rf.775faa7702fbf32bfc947af50e796551.txt', '/content/trafic_data/train/labels/Numan_-166-_jpg.rf.9efbfa2867b88fb996350fdb16a694ad.txt', '/content/trafic_data/train/labels/Navid_138_jpg.rf.16a862c939669d8dcc3f2da4f34b67ec.txt', '/content/trafic_data/train/labels/Dipto_-300_jpg.rf.afdc0edd6f4835f2870afecfb719648a.txt', '/content/trafic_data/train/labels/Dipto_635_jpg.rf.95edfd8e97ca16976fddbb5ecf312100.txt', '/content/trafic_data/train/labels/Dipto_830_jpg.rf.1158f0d0eb35ea7721975d828189e3d8.txt', '/content/trafic_data/train/labels/Dipto_784_jpg.rf.9ecc53720da1457e6dffe9c5614631bc.txt', '/content/trafic_data/train/labels/Navid_80_jpg.rf.b1df4063bed0ea91852227136f4c8cc1.txt', '/content/trafic_data/train/labels/Navid_410_jpg.rf.f385d8839b4e494f001beb46b0fee6cc.txt', '/content/trafic_data/train/labels/147_jpg.rf.530b8b682d735a1ecfa4708a5ca1b190.txt', '/content/trafic_data/train/labels/Dipto_-236_jpg.rf.9359c645bfb0ac5fb22e20b8f53b6f5f.txt', '/content/trafic_data/train/labels/Dipto_638_jpg.rf.f51fbb74602fe888e91be0d0e81ec0f1.txt', '/content/trafic_data/train/labels/143_jpg.rf.eb4bc1f58d2b8c88aa1128f7597ac6b4.txt', '/content/trafic_data/train/labels/Navid_651_JPG.rf.854699840628c82120dafafd8bc81b55.txt', '/content/trafic_data/train/labels/Dipto_14_jpg.rf.6a26a04c9b3acad9d4e0af8741b968df.txt', '/content/trafic_data/train/labels/Numan_-449-_jpg.rf.6ba40e9f4a4061c2236cae2661d088bd.txt', '/content/trafic_data/train/labels/220_jpg.rf.bb4fb2039b30af4430335bc68efea844.txt', '/content/trafic_data/train/labels/Dipto_-53_jpg.rf.032093765f6317eebcd033e0f3542d5f.txt', '/content/trafic_data/train/labels/Numan_-373-_jpg.rf.9a528803b1ba4392a884fabd2dfdadf8.txt', '/content/trafic_data/train/labels/Dipto_-219_jpg.rf.5a9b074fe1ecdd465e5fd397595ea6e5.txt', '/content/trafic_data/train/labels/65_jpeg.rf.6c0f3b5205fba66970fbe636f9b8bbea.txt', '/content/trafic_data/train/labels/Navid_517_jpg.rf.239a8f555065829bcb4965e062fa20df.txt', '/content/trafic_data/train/labels/Numan_--31-_jpg.rf.4f383f04a92e382b66dd7e4dcb7cf637.txt', '/content/trafic_data/train/labels/Navid_518_jpg.rf.167baecdfc66ec339bb22608e40d2fc0.txt', '/content/trafic_data/train/labels/148_jpg.rf.4d83b5d97809cb215d387e1306bf3c25.txt', '/content/trafic_data/train/labels/Navid_191_jpg.rf.7fbf1e3994610c62bcee13b195a7aa0e.txt', '/content/trafic_data/train/labels/Navid_587_JPG.rf.45d03da7495ef425e0dad7b5e3d0943f.txt', '/content/trafic_data/train/labels/Numan_-54-_jpg.rf.d230d81935c3494e12a406a7d0a09270.txt', '/content/trafic_data/train/labels/Navid_582_JPG.rf.a1a68975b086942239083159193109b1.txt', '/content/trafic_data/train/labels/Numan_-146-_jpg.rf.bd55107ea4e01850b101c37e51da14c0.txt', '/content/trafic_data/train/labels/85_jpg.rf.23d754dcb81727f702299ae5f1eb8f76.txt', '/content/trafic_data/train/labels/Navid_571_jpg.rf.9f69fa31efb0a15311ee1b50943ba389.txt', '/content/trafic_data/train/labels/Numan_-241-_jpg.rf.d25bd9db0fbc0305324a253c3c001cb4.txt', '/content/trafic_data/train/labels/Numan_-83-_jpg.rf.b3d222e020d3e1a4d8697ad1317f6d00.txt', '/content/trafic_data/train/labels/Dipto_497_jpg.rf.37d3bf00e19c64ad548d7edb72685361.txt', '/content/trafic_data/train/labels/135_jpg.rf.b62b97583f5fc4cde3601ba389453f23.txt', '/content/trafic_data/train/labels/Numan_-57-_jpg.rf.a7c2b8b97a5b483cb89eb391976020c9.txt', '/content/trafic_data/train/labels/Navid_691_jpg.rf.2ee2f7caa4854928ad8672ebb4e9c24f.txt', '/content/trafic_data/train/labels/124_jpg.rf.a0b15b3dd7ff027a849ac87774786146.txt', '/content/trafic_data/train/labels/Numan_-430-_jpg.rf.64eeb3238e5fc5b55e08250bda3ade15.txt', '/content/trafic_data/train/labels/Navid_654_JPG.rf.546814b6efb75623ee2152f79051db0b.txt', '/conten ...
